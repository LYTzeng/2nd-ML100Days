# %% [markdown]
#  # 請找出一個你認為機器學習可以發光發熱的領域並闡述原因?
#  在網路領域，軟體定義網路或許能結合機器學習，對網路架構進行壅塞預測和故障預測。因為以ISP而言，網路中"流"(Flow)的資料每天有非常多，資料中也具備非常多設備產生的封包資訊，比較不需要再進行標記。
#  當流量出現異常或設備卡版出錯，若能提前預測，配合自動化維運，能夠自動調整設定，節省人事成本。
